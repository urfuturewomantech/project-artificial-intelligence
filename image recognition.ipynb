# %% [markdown]
# # Library yang digunakan

# %%
# Import library
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import optimizers
from tensorflow.keras.optimizers import RMSprop

# %% [markdown]
# # Load data

# %%
# Load data
from tensorflow.keras.datasets import cifar10

# Load the training and test split of the cifar10 dataset
(training_images, training_labels), (test_images, test_labels) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 5s 0us/step

# %%
train_shape = training_images.shape
test_shape = test_images.shape

print(f'Terdapat {train_shape[0]} contoh dengan bentuk ({train_shape[1]}, {train_shape[2]}) dan dengan {train_shape[3]} warna pada data gambar latih')
print(f'Terdapat {test_shape[0]} contoh dengan bentuk ({test_shape[1]}, {test_shape[2]}) dan dengan {test_shape[3]} warna pada data gambar uji')
# Out:
# Terdapat 50000 contoh dengan bentuk (32, 32) dan dengan 3 warna pada data gambar latih
# Terdapat 10000 contoh dengan bentuk (32, 32) dan dengan 3 warna pada data gambar uji

# %%
plt.imshow(training_images[140]) #4 digit NPM
plt.axis('off')
plt.show()
print(f'LABEL: {training_labels[140]}') #4 digit NPM
# Out:
# LABEL: [1]

# %%
# Set number of characters per row when printing
np.set_printoptions(linewidth=320)
print(f'Bentuk dari sisi data: \n {training_images[3]}')
# Out:
# Bentuk dari sisi data:
#  [[[ 28  25  10]
#   [ 37  34  19]
#   [ 38  35  20]
#   ...
#   [ 76  67  39]
#   [ 81  72  43]
#   [ 85  76  47]]
#
#  [[ 33  28  13]
#   [ 34  30  14]
#   [ 32  27  12]
#   ...
#   [ 95  82  55]
#   [ 96  82  56]
#   [ 85  72  45]]
#
#  [[ 39  32  15]
#   [ 40  33  17]
#   [ 57  50  33]
#   ...
#   [ 93  76  52]
#   [107  89  66]
#   [ 95  77  54]]
#
#  ...
#
#  [[ 83  73  52]
#   [ 87  77  56]
#   [ 84  74  52]
#   ...
#   [ 99  93  70]
#   [ 90  84  61]
#   [ 81  75  52]]
#
#  [[ 88  72  51]
#   [ 90  74  52]
#   [ 93  77  56]
#   ...
#   [ 80  74  53]
#   [ 76  70  49]
#   [ 82  76  55]]
#
#  [[ 97  78  56]
#   [ 94  75  53]
#   [ 93  75  53]
#   ...
#   [ 54  47  28]
#   [ 63  56  37]
#   [ 72  65  46]]]

# %% [markdown]
# # Data Processing

# %%
# Normalisasi nilai piksel
training_images = training_images / 255.0
test_images = test_images / 255.0

# One-hot encoding
training_labels = to_categorical(training_labels)
test_labels = to_categorical(test_labels)

# %% [markdown]
# # Membangun Model

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu', input_shape = (32,32,3)),
    tf.keras.layers.MaxPooling2D(2,2), #mengurangi demensi gambar
    tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(), # menjadi vektor 1
    tf.keras.layers.Dropout(0.5), #mengurangi overviting
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax'),
])

# %%
model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(training_images, training_labels, epochs=15, batch_size=32, verbose=1, shuffle=True, validation_data=(test_images, test_labels))
# Out:
# Epoch 1/15
# 1563/1563 [==============================] - 22s 6ms/step - loss: 1.7941 - accuracy: 0.3486 - val_loss: 1.5631 - val_accuracy: 0.4342
# Epoch 2/15
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.4717 - accuracy: 0.4685 - val_loss: 1.3497 - val_accuracy: 0.5133
# Epoch 3/15
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.3319 - accuracy: 0.5254 - val_loss: 1.2401 - val_accuracy: 0.5683
# Epoch 4/15
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.2282 - accuracy: 0.5655 - val_loss: 1.1792 - val_accuracy: 0.5960
# Epoch 5/15
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.1529 - accuracy: 0.5938 - val_loss: 1.1465 - val_accuracy: 0.5976
# Epoch 6/15
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.0877 - accuracy: 0.6182 - val_loss: 1.0127 - val_accuracy: 0.6494
# Epoch 7/15
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.0361 - accuracy: 0.6344 - val_loss: 0.9958 - val_accuracy: 0.6550
# Epoch 8/15
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.9900 - accuracy: 0.6554 - val_loss: 0.9422 - val_accuracy: 0.6727
# Epoch 9/15
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.9518 - accuracy: 0.6685 - val_loss: 0.9126 - val_accuracy: 0.6880
# Epoch 10/15
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.9194 - accuracy: 0.6775 - val_loss: 0.9077 - val_accuracy: 0.6845
# Epoch 11/15
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8892 - accuracy: 0.6882 - val_loss: 0.8503 - val_accuracy: 0.7064
# Epoch 12/15
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8626 - accuracy: 0.6987 - val_loss: 0.8320 - val_accuracy: 0.7141
# Epoch 13/15
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8362 - accuracy: 0.7060 - val_loss: 0.8371 - val_accuracy: 0.7089
# Epoch 14/15
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8097 - accuracy: 0.7178 - val_loss: 0.8171 - val_accuracy: 0.7180
# Epoch 15/15
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7953 - accuracy: 0.7223 - val_loss: 0.8026 - val_accuracy: 0.7239

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

prodi = ['Matematika', 'Statistika', 'Biologi', 'Kimia', 'Teknik Informatika', 'Fisika']
jumlah_mhs = [108, 134, 167, 155, 120, 97]

plt.figure(figsize=(12,7))
plt.barh(prodi, jumlah_mhs, color='yellowgreen')

plt.title('Jumlah Mahasiswa Per Program Studi', size=16)
plt.xlabel('Jumlah Mahasiswa', size=14)
plt.xticks(size=12)
plt.yticks(size=12)

plt.show()

# %% [markdown]
# # Grafik

# %%
def plot_graphs(history, string, title):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.title(title)
  plt.show()

plot_graphs(history, "accuracy", "Accuracy Graphic")
plot_graphs(history, "loss", "Loss Graphic")

# %% [markdown]
# # Evaluasi dan Prediksi

# %%
# Mengevaluasi model pada data yang belum dilihat
eval = model.evaluate(test_images, test_labels)
print(f'Test loss: {eval[0]} \nTest accuracy: {eval[1]}')
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.8026 - accuracy: 0.7239
# Test loss: 0.8026260137557983
# Test accuracy: 0.7239000201225281

# %%
dict_label = {0:'airplane', 1:'automobile', 2:'bird',
              3:'cat', 4:'deer', 5:'dog',
              6:'frog', 7:'horse', 8:'ship', 9:'truck'}

def predict():
  some_random_number = np.random.randint(low=0, high=len(test_images)-1, size=4)
  sample_images = training_images[some_random_number]
  sample_label = training_labels[some_random_number]
  predicted = model.predict(sample_images)
  predicted = np.argmax(predicted, axis = 1)
  true_label = np.argmax(sample_label, axis = 1)
  fig, axs = plt.subplots(2, 2)
  for row in range(2):
    for col in range(2):
      if row == 0:
        true = true_label[row+col]
        pred = predicted[row+col]
        axs[row, col].imshow(sample_images[row+col])
      else:
        true = true_label[row+col+1]
        pred = predicted[row+col+1]
        axs[row,col].imshow(sample_images[row+col+1])
      axs[row,col].set_title('True : %s\nPredicted : %s' % (dict_label[true], dict_label[pred]))
      axs[row,col].axis('off')

predict()
# Out:
# 1/1 [==============================] - 0s 184ms/step
